# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
#MATPLOTLIB --> RGB
#OPENCV --> BGR

# %%
FXD_IMG =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(FXD_IMG)

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE) #gray scale so no channels present

# %%
#resizing img
plt.imshow(FXD_IMG)

# %%
FXD_IMG.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(FXD_IMG,(1000,400))
plt.imshow(new_img)

# %%
#resize by ratio
w_ratio = 0.8 # 80% of original and so on
h_ratio = 0.2
new_img = cv2.resize(FXD_IMG,(0,0), FXD_IMG,w_ratio,h_ratio)
plt.imshow(new_img)

# %%
#flip images
new_img = cv2.flip(FXD_IMG,-1)
plt.imshow(new_img)

# %%
type(FXD_IMG)
# Out:
# numpy.ndarray

# %%
#saving image
cv2.imwrite('totally_new_img.jpg',new_img)
# Out:
# True

# %% [markdown]
# ## Edge Detection

# %%
img = cv2.imread('DATA/sammy_face.jpg')
plt.imshow(img)

# %%
edges = cv2.Canny(image=img,threshold1=127,threshold2=127)
plt.imshow(edges)

# %%
edges = cv2.Canny(image=img,threshold1=0,threshold2=255)
plt.imshow(edges)

# %%
##Formula for thresholding
med_val = np.median(img)
lower = int(max(0, 0.7* med_val))# 30% less than median value
upper = int(min(255, 1.3* med_val)) # 30% more than median value

edges = cv2.Canny(image=img,threshold1=lower,threshold2=upper)
plt.imshow(edges)

# %%
## Blurring images to reduce noise
blurred_img = cv2.blur(img,ksize=(5,5))
edges = cv2.Canny(image=blurred_img,threshold1=lower,threshold2=upper)
plt.imshow(edges)
