# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('DATA/dog_backpack.jpg')

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=934x1401 at 0x21AE0E11550>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (1401, 934, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
#isolating channels- R G B
#red channel values
plt.imshow(pic_red[:,:,0],cmap='gray') #cmap = colormap, closer to white, more red
